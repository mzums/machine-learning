# %%
from fastai.vision.all import *

# %%
path = untar_data(URLs.BIWI_HEAD_POSE)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='452321280' class='' max='452316199' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [452321280/452316199 00:27&lt;00:00]
#     </div>

# %%
path.ls().sorted()
# Out:
# (#50) [Path('/home/mzums/.fastai/data/biwi_head_pose/01'),Path('/home/mzums/.fastai/data/biwi_head_pose/01.obj'),Path('/home/mzums/.fastai/data/biwi_head_pose/02'),Path('/home/mzums/.fastai/data/biwi_head_pose/02.obj'),Path('/home/mzums/.fastai/data/biwi_head_pose/03'),Path('/home/mzums/.fastai/data/biwi_head_pose/03.obj'),Path('/home/mzums/.fastai/data/biwi_head_pose/04'),Path('/home/mzums/.fastai/data/biwi_head_pose/04.obj'),Path('/home/mzums/.fastai/data/biwi_head_pose/05'),Path('/home/mzums/.fastai/data/biwi_head_pose/05.obj'),Path('/home/mzums/.fastai/data/biwi_head_pose/06'),Path('/home/mzums/.fastai/data/biwi_head_pose/06.obj'),Path('/home/mzums/.fastai/data/biwi_head_pose/07'),Path('/home/mzums/.fastai/data/biwi_head_pose/07.obj'),Path('/home/mzums/.fastai/data/biwi_head_pose/08'),Path('/home/mzums/.fastai/data/biwi_head_pose/08.obj'),Path('/home/mzums/.fastai/data/biwi_head_pose/09'),Path('/home/mzums/.fastai/data/biwi_head_pose/09.obj'),Path('/home/mzums/.fastai/data/biwi_head_pose/10'),Path('/home/mzums/.fastai/data/biwi_head_pose/10.obj')...]

# %%
(path/'01').ls().sorted()
# Out:
# (#1000) [Path('/home/mzums/.fastai/data/biwi_head_pose/01/depth.cal'),Path('/home/mzums/.fastai/data/biwi_head_pose/01/frame_00003_pose.txt'),Path('/home/mzums/.fastai/data/biwi_head_pose/01/frame_00003_rgb.jpg'),Path('/home/mzums/.fastai/data/biwi_head_pose/01/frame_00004_pose.txt'),Path('/home/mzums/.fastai/data/biwi_head_pose/01/frame_00004_rgb.jpg'),Path('/home/mzums/.fastai/data/biwi_head_pose/01/frame_00005_pose.txt'),Path('/home/mzums/.fastai/data/biwi_head_pose/01/frame_00005_rgb.jpg'),Path('/home/mzums/.fastai/data/biwi_head_pose/01/frame_00006_pose.txt'),Path('/home/mzums/.fastai/data/biwi_head_pose/01/frame_00006_rgb.jpg'),Path('/home/mzums/.fastai/data/biwi_head_pose/01/frame_00007_pose.txt'),Path('/home/mzums/.fastai/data/biwi_head_pose/01/frame_00007_rgb.jpg'),Path('/home/mzums/.fastai/data/biwi_head_pose/01/frame_00008_pose.txt'),Path('/home/mzums/.fastai/data/biwi_head_pose/01/frame_00008_rgb.jpg'),Path('/home/mzums/.fastai/data/biwi_head_pose/01/frame_00009_pose.txt'),Path('/home/mzums/.fastai/data/biwi_head_pose/01/frame_00009_rgb.jpg'),Path('/home/mzums/.fastai/data/biwi_head_pose/01/frame_00010_pose.txt'),Path('/home/mzums/.fastai/data/biwi_head_pose/01/frame_00010_rgb.jpg'),Path('/home/mzums/.fastai/data/biwi_head_pose/01/frame_00011_pose.txt'),Path('/home/mzums/.fastai/data/biwi_head_pose/01/frame_00011_rgb.jpg'),Path('/home/mzums/.fastai/data/biwi_head_pose/01/frame_00012_pose.txt')...]

# %%
img_files = get_image_files(path)
def img2pose(x): return Path(f'{str(x)[:-7]}pose.txt')
img2pose(img_files[0])
# Out:
# Path('/home/mzums/.fastai/data/biwi_head_pose/21/frame_00223_pose.txt')

# %%
im = PILImage.create(img_files[0])
im.shape
# Out:
# (480, 640)

# %%
im.to_thumb(160)
# Out:
# <PIL.Image.Image image mode=RGB size=160x120>

# %%
cal = np.genfromtxt(path/'01'/'rgb.cal', skip_footer=6)
def get_ctr(f):
    ctr = np.genfromtxt(img2pose(f), skip_header=3)
    c1 = ctr[0] * cal[0][0]/ctr[2] + cal[0][2]
    c2 = ctr[1] * cal[1][1]/ctr[2] + cal[1][2]
    return tensor([c1,c2])

# %%
biwi = DataBlock(
    blocks=(ImageBlock, PointBlock),
    get_items=get_image_files,
    get_y=get_ctr,
    splitter=FuncSplitter(lambda o: o.parent.name=='13'),
    batch_tfms=aug_transforms(size=(240,320)), 
)

# %%
dls = biwi.dataloaders(path)
dls.show_batch(max_n=9, figsize=(8, 6))

# %%
xb, yb = dls.one_batch()
xb.shape, yb.shape
# Out:
# (torch.Size([64, 3, 240, 320]), torch.Size([64, 1, 2]))

# %%
yb[0]
# Out:
# TensorPoint([[-0.0832, -0.0276]], device='cuda:0')

# %%
learn = vision_learner(dls,resnet18, y_range=(-1, 1))

# %%
def sigmoid_range(x, lo, hi): return torch.sigmoid(x) * (hi-lo) * lo

# %%
dls.loss_func
# Out:
# FlattenedLoss of MSELoss()

# %%
learn.lr_find()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# /home/mzums/miniconda3/envs/ml/lib/python3.12/site-packages/fastai/learner.py:53: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state = torch.load(file, map_location=device, **torch_load_kwargs)
# SuggestedLRs(valley=0.001737800776027143)

# %%
lr = 1e-2
learn.fine_tune(3, lr)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.046395</td>
#       <td>0.003710</td>
#       <td>00:38</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.007415</td>
#       <td>0.002293</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.002795</td>
#       <td>0.000864</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.001492</td>
#       <td>0.000333</td>
#       <td>00:46</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.show_results(ds_idx=1, nrows=3, figsize=(6,8))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
