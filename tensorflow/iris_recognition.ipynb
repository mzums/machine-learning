# %% [markdown]
# <a href="https://colab.research.google.com/github/mzums/machine-learning/blob/main/tensorflow/iris_recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import datasets
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
iris = datasets.load_iris()

#create featurs & labels
X=iris.data
y=iris.target

X
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
len(iris)
# Out:
# 8

# %%
# create training and test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=42)

# %%
tf.random.set_seed(42)

model = tf.keras.Sequential([
    tf.keras.layers.Dense(100),
    tf.keras.layers.Dense(10),
    tf.keras.layers.Dense(1)
])

model.compile(loss=tf.keras.losses.mae,
              optimizer="adam",
              metrics=["mae"])

model.fit(X_train, y_train, epochs=200)
# Out:
# Epoch 1/200
# 3/3 [==============================] - 1s 8ms/step - loss: 0.7659 - mae: 0.7659
# Epoch 2/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6106 - mae: 0.6106
# Epoch 3/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.4916 - mae: 0.4916
# Epoch 4/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3948 - mae: 0.3948
# Epoch 5/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.3003 - mae: 0.3003
# Epoch 6/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2441 - mae: 0.2441
# Epoch 7/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2640 - mae: 0.2640
# Epoch 8/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.2854 - mae: 0.2854
# Epoch 9/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2795 - mae: 0.2795
# Epoch 10/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.2522 - mae: 0.2522
# Epoch 11/200
# ...

# %%
from sklearn import neighbors
classifier=neighbors.KNeighborsClassifier()

classifier.fit(X_train,y_train)
model.evaluate(X_test, y_test)

predictions=classifier.predict(X_test)
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,predictions))
# Out:
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1987 - mae: 0.1987
# 0.9466666666666667

# %%
# USING DECISION TREES

from sklearn import  datasets
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.metrics import accuracy_score

iris=datasets.load_iris()
x=iris.data
y=iris.target

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.2)

classifier=tree.DecisionTreeClassifier()
classifier.fit(x_train,y_train)

predictions=classifier.predict(x_test)

print(accuracy_score(y_test,predictions))
# Out:
# 1.0

# %%
# USING NURAL NETWORKS

import tensorflow as tf
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Load the iris dataset
iris = datasets.load_iris()
x = iris.data
y = iris.target

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# Normalize the input features
x_train = tf.keras.utils.normalize(x_train)
x_test = tf.keras.utils.normalize(x_test)

# Define the neural network architecture
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(100, activation=tf.nn.relu),
    tf.keras.layers.Dense(50, activation=tf.nn.relu),
    tf.keras.layers.Dense(3, activation=tf.nn.softmax)
])

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train, epochs=200, batch_size=8)

# Make predictions on the test set
predictions = model.predict(x_test)
predicted_classes = tf.argmax(predictions, axis=1)

# Calculate accuracy
accuracy = accuracy_score(y_test, predicted_classes)
print("Accuracy:", accuracy)
# Out:
# Epoch 1/200
# 15/15 [==============================] - 1s 3ms/step - loss: 1.0660 - accuracy: 0.4083
# Epoch 2/200
# 15/15 [==============================] - 0s 3ms/step - loss: 1.0059 - accuracy: 0.7083
# Epoch 3/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.9470 - accuracy: 0.6833
# Epoch 4/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.8761 - accuracy: 0.6833
# Epoch 5/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.8010 - accuracy: 0.7083
# Epoch 6/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.7239 - accuracy: 0.6833
# Epoch 7/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6458 - accuracy: 0.6917
# Epoch 8/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.5788 - accuracy: 0.6917
# Epoch 9/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.5302 - accuracy: 0.8000
# Epoch 10/200
# ...
